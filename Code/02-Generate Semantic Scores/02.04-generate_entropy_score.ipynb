# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from previous step where subjectivity_score, flesch_index and polarity are calculated

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')
df.head(4)
# Out:
#          asin   helpful  ...  flesch_index polarity_score
# 0  6073894996    [3, 4]  ...          31.0       0.352083
# 1  9861203192  [25, 25]  ...          34.1       0.266970
# 2  9985537742  [10, 11]  ...          25.1       0.280476
# 3  998554627X    [5, 5]  ...          16.9       0.375000
#
# [4 rows x 10 columns]

# %%
df['preProcessed_reviewText'] = df['preProcessed_reviewText'].astype(str)

# %% [markdown]
# Add new column 'entropy_score' to dataframe

# %%
df['entropy_score'] = 0

# %% [markdown]
# Compute Entropy score for each review and store value in column 'entropy_score'

# %%
import math
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
length = len(df)
for i in range(length):
    review = df.iloc[i,6]
    fdist = FreqDist()
    for word in word_tokenize(review):
        fdist[word.lower()] += 1
    probs = [fdist.freq(l) for l in fdist]
    df.iloc[i,10] = -sum(p * math.log(p,2) for p in probs)

# %%
df.head(4)
# Out:
#          asin   helpful  overall  ... flesch_index polarity_score entropy_score
# 0  6073894996    [3, 4]      4.0  ...         31.0       0.352083      5.632935
# 1  9861203192  [25, 25]      5.0  ...         34.1       0.266970      5.800280
# 2  9985537742  [10, 11]      3.0  ...         25.1       0.280476      5.381458
# 3  998554627X    [5, 5]      5.0  ...         16.9       0.375000      5.064869
#
# [4 rows x 11 columns]

# %% [markdown]
# Save dataframe into same csv file so that new column will be added to it and can be used for further references

# %%
df.to_csv('Cell_Phones_and_Accessories.csv',index=False)

# %% [markdown]
# Check if all required columns are added to csv file

# %%
df = pd.read_csv('Cell_Phones_and_Accessories.csv')

# %%
df.head(4)
# Out:
#          asin   helpful  overall  ... flesch_index polarity_score entropy_score
# 0  6073894996    [3, 4]      4.0  ...         31.0       0.352083      5.632935
# 1  9861203192  [25, 25]      5.0  ...         34.1       0.266970      5.800280
# 2  9985537742  [10, 11]      3.0  ...         25.1       0.280476      5.381458
# 3  998554627X    [5, 5]      5.0  ...         16.9       0.375000      5.064869
#
# [4 rows x 11 columns]
