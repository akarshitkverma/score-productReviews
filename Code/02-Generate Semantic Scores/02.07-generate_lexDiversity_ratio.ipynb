# %% [markdown]
# Lexical Diversity is the ratio of unique words to total number of words in the review.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from preprocessing steps and after calculation of subjectivity score, flesch index, polarity score, entropy score, dale chall index, helpful ratio

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')
df.head(4)
# Out:
#          asin   helpful  overall  ... entropy_score daleChall_index helpful_ratio
# 0  6073894996    [3, 4]      4.0  ...      5.632935        6.568111      0.666667
# 1  9861203192  [25, 25]      5.0  ...      5.800280        7.892625      0.966667
# 2  9985537742  [10, 11]      3.0  ...      5.381458        7.162129      0.846154
# 3  998554627X    [5, 5]      5.0  ...      5.064869        8.279561      0.857143
#
# [4 rows x 13 columns]

# %% [markdown]
# Add new column 'Lex Diversity Ratio' to the dataframe

# %%
df['lexDiversity_ratio']=0

# %% [markdown]
# Computing Lex Diversity Ratio for each preProcessed review test using nltk library

# %%
from nltk import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import nltk
import nltk.data

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
raw_data=open('Cell_Phones_and_Accessories.csv').read()
raw_data[0:500]
# Out:
# 'asin,helpful,overall,reviewText,reviewTime,reviewerID,preProcessed_reviewText,subjectivity_score,flesch_index,polarity_score,entropy_score,daleChall_index,helpful_ratio\n6073894996,"[3, 4]",4.0,"This is a nice charger but you can tell it was made cheaply in China.  When it is charging the phone, the car radio gets LOTS of static.  Not so much that I have to stop charging but like when you are near power lines and the radio station is far away.So, no RF shielding.I gave it 4 stars because it works'

# %%
with open('Cell_Phones_and_Accessories.csv', 'r') as reader:
    moby_raw = reader.read()

# %%
moby_tokens = nltk.word_tokenize(moby_raw)
text = nltk.Text(moby_tokens)
moby_series = pd.Series(moby_tokens)

# %% [markdown]
# Function to Count the total number of words

# %%
def countToken():
     
    return len(moby_tokens)

MOBY_TOKEN_COUNT = countToken()
print("Dataset has {:,} words.".format(
     MOBY_TOKEN_COUNT))
# Out:
# Dataset has 5,645,727 words.

# %% [markdown]
# Function to count total number of unique words

# %%
def uniqueToken():
    
    return len(set(nltk.word_tokenize(moby_raw)))

MOBY_UNIQUE_COUNT = uniqueToken()
print("Dataset has {:,} unique words.".format(
    MOBY_UNIQUE_COUNT))
# Out:
# Dataset has 136,590 unique words.

# %% [markdown]
# Function for lexical diversity

# %%
def lexical_diversity(tokens):
   
    return len(set(tokens))/float(len(tokens))

# %%
def outputLexDiversity():
    
    return lexical_diversity(moby_tokens)

output = outputLexDiversity()
print("Lexical Diversity of Dataset: {:.2f}".format(output))
# Out:
# Lexical Diversity of Dataset: 0.02

# %% [markdown]
# Calculation the lexDiversity for review text

# %%
df['lexDiversity_ratio']=df['preProcessed_reviewText'].apply(lexical_diversity)

# %% [markdown]
# Lex Diversities

# %%
df.head(4)
# Out:
#          asin   helpful  ...  helpful_ratio lexDiversity_ratio
# 0  6073894996    [3, 4]  ...       0.666667           0.059278
# 1  9861203192  [25, 25]  ...       0.966667           0.055556
# 2  9985537742  [10, 11]  ...       0.846154           0.068452
# 3  998554627X    [5, 5]  ...       0.857143           0.108696
#
# [4 rows x 14 columns]

# %% [markdown]
# Adding the Lex Diversity Ratios to the original csv

# %%
df.to_csv('Cell_Phones_and_Accessories.csv',index=False)

# %% [markdown]
# Checking if the new computed values are added to the dataframe

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')

# %%
df.head(4)
# Out:
#          asin   helpful  ...  helpful_ratio lexDiversity_ratio
# 0  6073894996    [3, 4]  ...       0.666667           0.059278
# 1  9861203192  [25, 25]  ...       0.966667           0.055556
# 2  9985537742  [10, 11]  ...       0.846154           0.068452
# 3  998554627X    [5, 5]  ...       0.857143           0.108696
#
# [4 rows x 14 columns]
