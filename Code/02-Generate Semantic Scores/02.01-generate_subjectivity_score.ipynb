# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from preprocessing step

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')
df.head(4)
# Out:
#          asin  ...                            preProcessed_reviewText
# 0  6073894996  ...  this is a nice charger but you can tell it was...
# 1  9861203192  ...  bought this for my new att galaxy sii the case...
# 2  9985537742  ...  works fine if you dont move the phone  if you ...
# 3  998554627X  ...  was somewhat concerned after reading some of t...
#
# [4 rows x 7 columns]

# %%
df['preProcessed_reviewText']=df['preProcessed_reviewText'].astype(str)

# %% [markdown]
# Add new column 'subjectivity_score' to dataframe

# %%
df['subjectivity_score']=0

# %% [markdown]
# Compute Subjectivity score for each review and store value in column 'subjectivity_score'

# %%
from textblob import TextBlob

# %%
length=len(df)
for i in range(length):
  review=df.iloc[i,6]
  subjectivityScore=TextBlob(review).sentiment.subjectivity
  df.iloc[i,7]=subjectivityScore

# %%
df.head(4)
# Out:
#          asin  ... subjectivity_score
# 0  6073894996  ...           0.650000
# 1  9861203192  ...           0.562121
# 2  9985537742  ...           0.500000
# 3  998554627X  ...           0.575000
#
# [4 rows x 8 columns]

# %% [markdown]
# Save dataframe into same csv file so that new column will be added to it and can be used for further references

# %%
df.to_csv('Cell_Phones_and_Accessories.csv',index=False)

# %% [markdown]
# Check if all required columns are added to csv file

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')

# %%
df.head(4)
# Out:
#          asin  ... subjectivity_score
# 0  6073894996  ...           0.650000
# 1  9861203192  ...           0.562121
# 2  9985537742  ...           0.500000
# 3  998554627X  ...           0.575000
#
# [4 rows x 8 columns]
