# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from previous step where semantic scores are calculated

# %%
df=pd.read_csv("Cell_Phones_and_Accessories.csv")

# %%
df.head(4)
# Out:
#          asin   helpful  ...  lexDiversity_ratio normalized_flesch_index
# 0  6073894996    [3, 4]  ...            0.059278                0.013262
# 1  9861203192  [25, 25]  ...            0.055556                0.014807
# 2  9985537742  [10, 11]  ...            0.068452                0.010320
# 3  998554627X    [5, 5]  ...            0.108696                0.006232
#
# [4 rows x 15 columns]

# %% [markdown]
# Check minimum and maximum values of 'polarity_score'

# %%
print(df['polarity_score'].min())
# Out:
# -1.0

# %%
print(df['polarity_score'].max())
# Out:
# 1.0

# %% [markdown]
# Since minimum and maximum value of 'polarity_score' are not 0 and 1 respectively, the 'polarity_score'needs to be computed in normalized format. Thus, we will perform following steps of normalization on it.

# %% [markdown]
# Add new column 'normalized_polarity' to dataframe

# %%
df['normalized_polarity_score']=0

# %%
length=len(df)
minIndex=df['polarity_score'].min()
maxIndex=df['polarity_score'].max()
for i in range(length):
  index=df.iloc[i,9]
  normalizedIndex=(index-minIndex)/(maxIndex-minIndex)
  df.iloc[i,15]=normalizedIndex

# %%
df.head(4)
# Out:
#          asin   helpful  ...  normalized_flesch_index normalized_polarity_score
# 0  6073894996    [3, 4]  ...                 0.013262                  0.676042
# 1  9861203192  [25, 25]  ...                 0.014807                  0.633485
# 2  9985537742  [10, 11]  ...                 0.010320                  0.640238
# 3  998554627X    [5, 5]  ...                 0.006232                  0.687500
#
# [4 rows x 16 columns]

# %% [markdown]
# Save dataframe into same csv file so that new column will be added to it and can be used for further references

# %%
df.to_csv("Cell_Phones_and_Accessories.csv",index=False)

# %% [markdown]
# Check if all required columns are added to csv file

# %%
df=pd.read_csv("Cell_Phones_and_Accessories.csv")

# %%
df.head(4)
# Out:
#          asin   helpful  ...  normalized_flesch_index normalized_polarity_score
# 0  6073894996    [3, 4]  ...                 0.013262                  0.676042
# 1  9861203192  [25, 25]  ...                 0.014807                  0.633485
# 2  9985537742  [10, 11]  ...                 0.010320                  0.640238
# 3  998554627X    [5, 5]  ...                 0.006232                  0.687500
#
# [4 rows x 16 columns]
