# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWj59zAOpsttXC-KcCgJvOvnJ62SxHZhfQoZkL68JXH0mZ9DM9owEhk
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from previous step where semantic scores are calculated

# %%
df=pd.read_csv("Cell_Phones_and_Accessories.csv");

# %%
df.head(4)
# Out:
#          asin   helpful  ...  helpful_ratio lexDiversity_ratio
# 0  6073894996    [3, 4]  ...       0.666667           0.059278
# 1  9861203192  [25, 25]  ...       0.966667           0.055556
# 2  9985537742  [10, 11]  ...       0.846154           0.068452
# 3  998554627X    [5, 5]  ...       0.857143           0.108696
#
# [4 rows x 14 columns]

# %% [markdown]
# Check minimum and maximum values of 'subjectivity_score'

# %%
print(df['subjectivity_score'].min())
# Out:
# 0.0

# %%
print(df['subjectivity_score'].max())
# Out:
# 1.0

# %% [markdown]
# Since minimum and maximum value of 'subjectivity_score' are 0 and 1 respectively, the 'subjectivity_score' is already in normalized format. Thus, we do not need to perform steps of normalization on it.
