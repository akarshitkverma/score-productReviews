# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data
# Out:
# /content/gdrive/MyDrive/Utility-Scoring-Of-Product-Reviews/Data

# %% [markdown]
# Read dataset obtained from previous step where semantic scores are calculated

# %%
df=pd.read_csv("Cell_Phones_and_Accessories.csv")

# %%
df.head(4)
# Out:
#          asin   helpful  ...  normalized_entropy_score normalized_daleChall_index
# 0  6073894996    [3, 4]  ...                  0.384745                   0.393515
# 1  9861203192  [25, 25]  ...                  0.416500                   0.477973
# 2  9985537742  [10, 11]  ...                  0.337025                   0.431393
# 3  998554627X    [5, 5]  ...                  0.276950                   0.502646
#
# [4 rows x 18 columns]

# %% [markdown]
# Add new column 'utility_score' to dataframe

# %%
df['utility_score'] = 0

# %% [markdown]
# Calculating the target varible 'utility_score'

# %%
length=len(df)
minIndex=df['asin'].min()
maxIndex=df['asin'].max()
for i in range(length):
  uStr=df.iloc[i,1]
  uStr = uStr.strip('[]')
  uList = uStr.split(',')
  uList = [int(num) for num in uList]
  ratio=(uList[0])/(uList[0]+uList[1])
  df.iloc[i,18]=ratio

# %%
df.head(4)
# Out:
#          asin   helpful  ...  normalized_daleChall_index utility_score
# 0  6073894996    [3, 4]  ...                    0.393515      0.428571
# 1  9861203192  [25, 25]  ...                    0.477973      0.500000
# 2  9985537742  [10, 11]  ...                    0.431393      0.476190
# 3  998554627X    [5, 5]  ...                    0.502646      0.500000
#
# [4 rows x 19 columns]

# %% [markdown]
# Adding the utility_score to the original csv

# %%
df.to_csv('Cell_Phones_and_Accessories.csv',index=False)

# %% [markdown]
# Checking if the new computed values are added to the dataframe

# %%
df=pd.read_csv('Cell_Phones_and_Accessories.csv')

# %%
df.head(4)
# Out:
#          asin   helpful  ...  normalized_daleChall_index utility_score
# 0  6073894996    [3, 4]  ...                    0.393515      0.428571
# 1  9861203192  [25, 25]  ...                    0.477973      0.500000
# 2  9985537742  [10, 11]  ...                    0.431393      0.476190
# 3  998554627X    [5, 5]  ...                    0.502646      0.500000
#
# [4 rows x 19 columns]
